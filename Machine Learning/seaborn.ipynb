# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset('tips')
# sns.lineplot(data=tips, x='total_bill', y='tip')
# plt.title('Scatter plot of total bill vs tip')
# plt.show()  
# sns.barplot(data=tips, x='day', y='total_bill', hue='sex')
# plt.title('Bar plot of total bill by day and sex')
# plt.show()
# gives a bar plot of the total bill variable in the tips dataset, with separate bars for each day of the week and colored by the 'sex' variable
# sns.boxplot(data=tips, x='day', y='total_bill', hue='sex')
# plt.title('Box plot of total bill by day and sex')  
# plt.show()
# gives a violin plot of the total bill variable in the tips dataset, with separate violins for each day of the week and colored by the 'sex' variable
# sns.histplot(data=tips, x='total_bill', bins=10, kde=True)
# plt.title('Histogram of total bill with KDE')
# plt.show()
# gives a KDE plot of the total bill variable in the tips dataset, with separate curves
# sns.kdeplot(data=tips, x='total_bill', hue='sex', fill=True)
# plt.title('KDE plot of total bill by sex')
# plt.show()
# gives a pair plot of the tips dataset, which shows scatter plots and histograms for all pairs of numerical variables in the dataset, colored by the 'sex' variable
sns.pairplot(data=tips, hue='sex')
plt.title('Pair plot of tips dataset by sex')
plt.show()

# %%
# heatmap will give a heatmap of the correlation matrix of the numerical variables in the tips dataset, with annotations showing the correlation coefficients
corr=tips[['total_bill', 'tip', 'size']].corr()
corr
sns.heatmap(corr,annot=True, cmap='coolwarm')
# Out:
# <Axes: >

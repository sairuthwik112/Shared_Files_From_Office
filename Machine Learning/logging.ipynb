# %% [markdown]
# Logging Levels
#
# DEBUG
#
# Detailed information for developers.
# Used for troubleshooting and debugging.
# Shows variable values and step-by-step execution.
# Memory: DEBUG = How is it happening?
#
# Example: DEBUG: Source = Hyderabad DEBUG: Found 50 attractions
#
# INFO
#
# Normal application events.
# Confirms successful operations.
# Memory: INFO = What happened?
#
# Example: INFO: Route generated successfully INFO: User logged in
#
# WARNING
#
# Something unexpected happened.
# Program can still continue.
# Memory: WARNING = Be careful
#
# Example: WARNING: No attractions found WARNING: API response is slow
#
# ERROR
#
# An operation failed.
# Part of the application may stop working.
# Memory: ERROR = Something failed
#
# Example: ERROR: Database connection failed ERROR: API request failed
#
# CRITICAL
#
# Severe system failure.
# Application may stop completely.
# Memory: CRITICAL = Everything is broken
#
# Example: CRITICAL: Server crashed CRITICAL: Application cannot start
#
# Order of Severity
#
# DEBUG < INFO < WARNING < ERROR < CRITICAL
#
# AI Route Explorer Example
#
# DEBUG -> User interest = Nature DEBUG -> Found 47 attractions
#
# INFO -> Route generated successfully
#
# WARNING -> No attractions within 5 km
#
# ERROR -> Overpass API request failed
#
# CRITICAL -> Backend service unavailable
#
# Interview Definition
#
# Logging levels categorize log messages based on importance:
#
# DEBUG for detailed debugging information.
# INFO for normal events.
# WARNING for potential issues.
# ERROR for failures.
# CRITICAL for severe system failures.

# %%
import logging

logging.basicConfig(
    filename='app.log',      # Log file name
    filemode='w',            # w = overwrite file every run
    level=logging.DEBUG,     # Minimum level to log
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

print("Logs written to app.log")
# Out:
# Logs written to app.log

# %%
def add(a,b):
    logging.debug('Addition of two numbers is printing....')
    return a+b
add(1,2)
# Out:
# 3

# %%
# Logging with multiple loggers 
logger1=logging.getLogger("Module 1")
logger1.setLevel(logging.DEBUG)
logger2=logging.getLogger("Module 2")
logger2.setLevel(logging.WARNING)
logging.basicConfig(
    filename='app.log',      # Log file name
    filemode='w',            # w = overwrite file every run
    level=logging.DEBUG,     # Minimum level to log
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
# with small application
logger=logging.getLogger("Arithmetic_Operations")
logging.basicConfig(
    # filename='app.log',      # Log file name
    # filemode='w',            # w = overwrite file every run
    level=logging.DEBUG,     # Minimum level to log
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    handlers=[
        logging.FileHandler("app.log"),
        logging.StreamHandler()
    ]
)
logger=logging.getLogger("Arithmetic_Operations")
def add(a, b):
    result = a + b
    logger.debug(f"Addition: {a} + {b} = {result}")
    return result

def subtract(a, b):
    result = a - b
    logger.debug(f"Subtraction: {a} - {b} = {result}")
    return result

def multiply(a, b):
    result = a * b
    logger.debug(f"Multiplication: {a} * {b} = {result}")
    return result

def divide(a, b):
    try:
        result = a / b
        logger.debug(f"Division: {a} / {b} = {result}")
        return result

    except ZeroDivisionError:
        logger.error("Cannot divide by zero")
        print("Error: Cannot divide by zero")

# Function calls
print(add(10, 5))
print(subtract(10, 5))
print(multiply(10, 5))
print(divide(10, 2))
print(divide(10, 0))
# Out:
# 15
# 5
# 50
# 5.0
# Error: Cannot divide by zero
# None
